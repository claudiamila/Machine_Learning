# %%
import numpy

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Iris.csv')

# %%
dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
dataset.head(5) #show 5 teratas
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dataset.groupby('Species').size() #row per species
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
#drop ID
dataset = dataset.drop(['Id'], axis = 1)  
dataset
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# 6              4.6           3.4            1.4           0.3     Iris-setosa
# 7              5.0           3.4            1.5           0.2     Iris-setosa
# 8              4.4           2.9            1.4           0.2     Iris-setosa
# 9              4.9           3.1            1.5           0.1     Iris-setosa
# 10             5.4           3.7            1.5           0.2     Iris-setosa
# ...

# %%
dataset.info()   # getting an insight into the type of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
import seaborn as sns
from sklearn import metrics
from sklearn import preprocessing  
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
sns.pairplot(dataset)  # to show relation between columns
plt.show()

# %%
corr = dataset.corr()
sns.heatmap(corr, annot=True)  # quantifying the relationship

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
#data['Species'] = label_encoder.fit_transform(data['Species'])   # label encoding 'Species' column
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-9a8d11e7b2bf> in <module>
# ----> 1 data['Species'] = label_encoder.fit_transform(data['Species'])   # label encoding 'Species' column
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
#dataset.groupby('species').size() #menampilkan row masing-masing spesies

# %%
dataset
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# 6              4.6           3.4            1.4           0.3     Iris-setosa
# 7              5.0           3.4            1.5           0.2     Iris-setosa
# 8              4.4           2.9            1.4           0.2     Iris-setosa
# 9              4.9           3.1            1.5           0.1     Iris-setosa
# 10             5.4           3.7            1.5           0.2     Iris-setosa
# ...

# %%
#dataset['Species'] = dataset['Species'].astype('int32')

# %%
#visualisasi : sns.pairplot(hue="Species", data = dataset)
#dataframe to array
data=dataset.values

#split 
X, y = data[:,:-1], data[:,-1]
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.20, random_state=0)

# %%
# letting k = 5
k = 5
# training model and predicting  
kclf = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
kclf
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred = kclf.predict(X_test)

# %%
y_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, kclf.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# Train set Accuracy:  0.95
# Test set Accuracy:  0.9666666666666667

# %%
#visualisasi : 
sns.pairplot(hue="Species", data = dataset)

# %%
df_xtest=pd.DataFrame(X_test, columns=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']) 
#sns.pairplot(hue="Species", data = X_test)

# %%
df_xtest.head()
# Out:
#   SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm
# 0           5.8          2.8           5.1          2.4
# 1             6          2.2             4            1
# 2           5.5          4.2           1.4          0.2
# 3           7.3          2.9           6.3          1.8
# 4             5          3.4           1.5          0.2

# %%
ytest = pd.DataFrame(y_test, columns=['Species'])

# %%
df=pd.concat([df_xtest,ytest],axis=1)

# %%
df.head()
# Out:
#   SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm          Species
# 0           5.8          2.8           5.1          2.4   Iris-virginica
# 1             6          2.2             4            1  Iris-versicolor
# 2           5.5          4.2           1.4          0.2      Iris-setosa
# 3           7.3          2.9           6.3          1.8   Iris-virginica
# 4             5          3.4           1.5          0.2      Iris-setosa

# %%
sns.pairplot(hue="Species", data=df)

# %%
pred = pd.DataFrame(y_pred, columns=['Species'])

# %%
df_pred=pd.concat([df_xtest,pred],axis=1)

# %%
sns.pairplot(hue="Species", data=df_pred)

# %%
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30
